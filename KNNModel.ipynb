# %% [markdown]
# KNN Model Lab2
# The first thing that needs to be done is to import anything that will be used for performing the KNN Model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.metrics import classification_report

# %% [markdown]
# We need to load in our file that has been cleaned.

# %%
data = pd.read_csv('Students_Grade.csv')

# %% [markdown]
# Each kind of analysis needs different sorts of preprocessing to be most efficient, the following code is to check and see if everything looks ready to go.

# %%
print(data.head())
print(data.isnull().sum())
# Out:
#   Student_ID First_Name Last_Name  Gender  Age  Department  Attendance (%)  \
# 0      S1000       Omar  Williams       0   22           2           52.29
# 1      S1001      Maria     Brown       1   18           2           97.27
# 2      S1002      Ahmed     Jones       1   24           0           57.19
# 3      S1003       Omar  Williams       0   24           3           95.15
# 4      S1004       John     Smith       0   23           1           54.18
#
#    Midterm_Score  Final_Score  Assignments_Avg  ...  Projects_Score  \
# 0          55.03        57.82            84.22  ...           85.90
# 1          97.23        45.80              NaN  ...           55.65
# 2          67.05        93.68            67.70  ...           73.79
# 3          47.79        80.63            66.06  ...           92.12
# 4          46.59        78.89            96.85  ...           68.42
#
#    Total_Score  Grade  Study_Hours_per_Week  Extracurricular_Activities  \
# ...

# %% [markdown]
# We need to make sure that data is set in a manner the facilitates the KNN Model well so we use the following code to reduce problematic object values

# %%
data = data.drop(data.select_dtypes(include='object').columns, axis=1)

# %% [markdown]
# For any remaining problematic data we impute the mean for any NaN values and transform the column to their new contents.

# %%
imputer = SimpleImputer(strategy='mean')
data = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# %% [markdown]
# We need to set the target for analysis so we tell the model to ignore a certain column

# %%
X = data.iloc[:, :-8]
y = data.iloc[:, -8]

# %% [markdown]
# Now that we have set the features and targets we have to split the data into corresponding train and test sets for X & Y. Random state makes sure that the data split is consistent across all sets.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=94)

# %% [markdown]
# We are now going to use scaler to standardize the data to have a mean of 0 and a standard deviation of 1. We do this to ensure consistency between the training and test sets.

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# We now start the KNN Model and set it to examine the closest 5 neighbors to make predictions.

# %%
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust n_neighbors
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# We now use the KNN Model to predict labels for neighbor values

# %%
y_pred = knn.predict(X_test)

# %% [markdown]
# Now that we have set the model to make predictions we can use the code to measure its performance for; Accuracy, Precision, Recall, and F-1 Score.

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.286
#               precision    recall  f1-score   support
#
#          0.0       0.20      0.24      0.22       180
#          1.0       0.25      0.27      0.26       185
#          2.0       0.19      0.19      0.19       149
#          3.0       0.22      0.22      0.22       185
#          4.0       0.51      0.41      0.45       301
#
#     accuracy                           0.29      1000
#    macro avg       0.27      0.27      0.27      1000
# weighted avg       0.30      0.29      0.29      1000
